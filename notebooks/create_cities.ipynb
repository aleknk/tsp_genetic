# %%
import numpy as np
from pytsp.cities import generate_cities, plot_cities

# %%
# Set params
save_path = "../data/cities_example.npy"
n, min_val, max_val = 50, 0, 100

# Create cities
cities = generate_cities(n=n, min_val=min_val, max_val=max_val)

# Plot cities
plot_cities(cities)

# Save cities
np.save(save_path, cities)
